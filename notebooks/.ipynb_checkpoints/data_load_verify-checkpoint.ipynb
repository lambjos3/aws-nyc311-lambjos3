# %%
# Test 1: Import key libraries
import pandas as pd
import boto3
import numpy as np

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
# Test 2: Connect to S3
s3 = boto3.client('s3')
response = s3.list_buckets()
bucket_count = len(response['Buckets'])

print(f"Connected to S3")
print(f"Found {bucket_count} S3 buckets")

# Print your buckets (to identify your modeling data bucket)
for bucket in response['Buckets']:
    print(f"  - {bucket['Name']}")
# Out:
# Connected to S3
# Found 1 S3 buckets
#   - cmse495-lambjos3-nyc311-381491926400-us-east-1-an

# %%
import pandas as pd
import boto3
from io import StringIO

s3 = boto3.client('s3')
bucket_name = 'cmse495-lambjos3-nyc311-381491926400-us-east-1-an'
file_name = 'modeling/resolution_time_modeling.csv' 

obj = s3.get_object(Bucket=bucket_name, Key=file_name)
data = obj['Body'].read().decode('utf-8')
df = pd.read_csv(StringIO(data))

# %%
# First few rows
print("First few rows:")
print(df.head())

# Data types and missing values
print("\n" + "="*50)
print("Data types and missing values:")
print(df.info())
# Out:
# First few rows:
#   agency        borough             problem  incident_zip  day_of_week  \
# 0   DCWP  STATEN ISLAND  Consumer Complaint       10309.0            6
# 1   DCWP         QUEENS  Consumer Complaint       11418.0            6
# 2   DCWP       BROOKLYN  Consumer Complaint       11203.0            6
# 3   DCWP       BROOKLYN  Consumer Complaint       11233.0            6
# 4   DCWP      MANHATTAN  Consumer Complaint       10019.0            6
#
#    hour_of_day  same_day_complaint_volume  days_to_close
# 0            9                         17             31
# 1           13                         17              1
# 2           22                         17             45
# 3           12                         17              1
# 4           11                         17             31
#
# ...
# Data types and missing values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173851 entries, 0 to 173850
# Data columns (total 8 columns):
# ...

# %%
# Summary statistics
print("Summary statistics:")
print(df.describe())
# Out:
# Summary statistics:
#         incident_zip    day_of_week    hour_of_day  same_day_complaint_volume  \
# count  172086.000000  173851.000000  173851.000000              173851.000000
# mean    10838.974629       3.898614      13.006040                 437.072085
# std       528.743746       1.990228       6.034949                 647.101016
# min     10000.000000       1.000000       0.000000                   1.000000
# 25%     10452.000000       2.000000       9.000000                  51.000000
# 50%     11205.000000       4.000000      13.000000                 260.000000
# 75%     11235.000000       6.000000      18.000000                 559.000000
# max     11697.000000       7.000000      23.000000                3759.000000
#
#        days_to_close
# count  173851.000000
# mean        2.061656
# std         5.120339
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max        49.000000

# %%
print("Target distribution (days to close):")
print(df['days_to_close'].value_counts().sort_index())

# As percentage
print("\nTarget distribution (%)")
print((df['days_to_close'].value_counts() / len(df) * 100).sort_index().round(2))
# Out:
# Target distribution (days to close):
# days_to_close
# 0     107909
# 1      17700
# 2      12346
# 3       8184
# 4       5827
# 5       4598
# 6       3137
# 7       1935
# 8       1420
# 9       1255
# 10       847
# 11       733
# 12       697
# 13       619
# 14       556
# 15       499
# 16       450
# 17       434
# 18       377
# 19       392
# 20       322
# 21       286
# 22       271
# 23       266
# 24       215
# 25       225
# 26       231
# 27       186
# 28       169
# 29       170
# 30       225
# 31       153
# 32       161
# 33       137
# 34        97
# 35       106
# 36        98
# 37        76
# 38        79
# 39        69
# 40        85
# 41        70
# 42        53
# 43        37
# 44        34
# 45        39
# 46        29
# 47        16
# 48        19
# 49        12
# Name: count, dtype: int64
#
# Target distribution (%)
# days_to_close
# 0     62.07
# 1     10.18
# 2      7.10
# 3      4.71
# 4      3.35
# 5      2.64
# 6      1.80
# 7      1.11
# ...
